# %% [markdown]
# ## EDA - IPL - TASK 3 - Shivani Vashishta

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-whitegrid') 
import seaborn as sns

# %%
deliveries = pd.read_csv("deliveries.csv")
matches = pd.read_csv("matches.csv")

# %%
deliveries.head(10)
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 5         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 6         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 7         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 8         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 9         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
#
#    ball    batsman non_striker       bowler  is_super_over  ...  bye_runs  \
# ...

# %%
matches.head(10)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 8   9    2017       Pune  2017-04-11             Delhi Daredevils
# 9  10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
deliveries.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
matches.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %% [markdown]
# ## All teams

# %%
teams = matches["team1"].unique()
teams
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
totalrunsofeachteamarr = []
for i in teams :
    temp = deliveries.loc[(deliveries["batting_team"] == i),["batting_team","total_runs"]]
    tempruns = temp["total_runs"].count()
    totalrunsofeachteamarr.append(tempruns)
totalrunsofeachteamarr
# Out:
# [12908,
#  22619,
#  3566,
#  1900,
#  20908,
#  20858,
#  18786,
#  20931,
#  19762,
#  17292,
#  9034,
#  1582,
#  5443,
#  1580,
#  1909]

# %% [markdown]
# ## Runs scored by each team

# %%
totalrunsofeachteam = pd.DataFrame({"Team" : teams,"Total runs of each team" : totalrunsofeachteamarr}, columns = ["Team", "Total runs of each team"]).set_index("Team")
totalrunsofeachteam.sort_values(by="Total runs of each team", ascending=False,inplace = True)
totalrunsofeachteam
# Out:
#                              Total runs of each team
# Team
# Mumbai Indians                                 22619
# Kings XI Punjab                                20931
# Royal Challengers Bangalore                    20908
# Kolkata Knight Riders                          20858
# Chennai Super Kings                            19762
# Delhi Daredevils                               18786
# Rajasthan Royals                               17292
# Sunrisers Hyderabad                            12908
# Deccan Chargers                                 9034
# Pune Warriors                                   5443
# Gujarat Lions                                   3566
# Delhi Capitals                                  1909
# Rising Pune Supergiant                          1900
# Kochi Tuskers Kerala                            1582
# Rising Pune Supergiants                         1580

# %% [markdown]
# ## Result : Highest number of runs are scored by Mumbai Indians

# %%
plt.figure(figsize=(14,14))
sns.barplot(totalrunsofeachteam["Total runs of each team"],totalrunsofeachteam.index, palette ="deep")

# %%
batsman = deliveries["batsman"].unique()
batsman
# Out:
# array(['DA Warner', 'S Dhawan', 'MC Henriques', 'Yuvraj Singh',
#        'DJ Hooda', 'BCJ Cutting', 'CH Gayle', 'Mandeep Singh', 'TM Head',
#        'KM Jadhav', 'SR Watson', 'Sachin Baby', 'STR Binny', 'S Aravind',
#        'YS Chahal', 'TS Mills', 'A Choudhary', 'PA Patel', 'JC Buttler',
#        'RG Sharma', 'N Rana', 'AT Rayudu', 'KH Pandya', 'KA Pollard',
#        'HH Pandya', 'TG Southee', 'AM Rahane', 'MA Agarwal', 'SPD Smith',
#        'BA Stokes', 'MS Dhoni', 'JJ Roy', 'BB McCullum', 'SK Raina',
#        'AJ Finch', 'KD Karthik', 'G Gambhir', 'CA Lynn', 'MK Tiwary',
#        'DT Christian', 'HM Amla', 'M Vohra', 'WP Saha', 'AR Patel',
#        'GJ Maxwell', 'DA Miller', 'Vishnu Vinod', 'Iqbal Abdulla',
#        'P Negi', 'AP Tare', 'SW Billings', 'KK Nair', 'SV Samson',
#        'RR Pant', 'CH Morris', 'CR Brathwaite', 'PJ Cummins', 'A Mishra',
#        'S Nadeem', 'Z Khan', 'DR Smith', 'DS Kulkarni', 'P Kumar',
# ...

# %%
totalrunseachbatsmanarr = []
for i in batsman :
    temp1 = deliveries.loc[deliveries["batsman"]==i,["batsman","batsman_runs"]]
    temp2 = temp1["batsman_runs"].sum()
    totalrunseachbatsmanarr.append(temp2)
totalrunseachbatsmanarr
# Out:
# [4741,
#  4632,
#  969,
#  2765,
#  535,
#  240,
#  4560,
#  1547,
#  205,
#  1091,
#  3614,
#  137,
#  882,
#  59,
#  22,
#  8,
#  25,
#  2874,
#  1431,
#  4914,
#  1104,
#  3326,
#  915,
#  2784,
#  1118,
#  115,
#  3850,
#  1276,
#  2047,
#  647,
#  4477,
#  186,
#  2893,
#  5415,
#  1744,
#  3688,
#  4223,
#  1308,
#  1697,
#  448,
#  577,
#  1016,
#  1780,
#  806,
#  1403,
#  1875,
#  19,
#  88,
#  366,
#  339,
#  338,
#  1470,
#  2235,
#  1792,
#  520,
#  188,
#  77,
#  368,
#  32,
#  117,
#  2385,
#  101,
#  340,
#  32,
#  4446,
#  2872,
#  3241,
#  608,
#  63,
#  803,
#  834,
#  4428,
#  538,
#  1874,
#  771,
#  342,
#  73,
#  5,
#  26,
#  20,
#  1555,
#  574,
#  109,
#  190,
#  482,
#  124,
#  49,
#  5434,
#  91,
#  164,
#  36,
#  15,
#  1,
#  313,
#  187,
#  1714,
#  854,
#  24,
#  26,
#  711,
#  55,
#  7,
#  13,
#  724,
#  54,
#  146,
#  55,
#  1951,
#  94,
#  1319,
#  2489,
#  759,
#  527,
#  168,
#  70,
#  91,
#  52,
#  46,
#  127,
#  79,
#  317,
#  6,
#  12,
#  38,
# ...

# %%
totalrunseachbatsman = pd.DataFrame({"Batsman" : batsman,"Total runs by each Batsman" : totalrunseachbatsmanarr}, columns = ["Batsman", "Total runs by each Batsman"]).set_index("Batsman")
totalrunseachbatsman.sort_values(by="Total runs by each Batsman", ascending = False,inplace=True)
top25batsmanruns = totalrunseachbatsman["Total runs by each Batsman"].nlargest(25)
top25batsmanruns
# Out:
# Batsman
# V Kohli           5434
# SK Raina          5415
# RG Sharma         4914
# DA Warner         4741
# S Dhawan          4632
# CH Gayle          4560
# MS Dhoni          4477
# RV Uthappa        4446
# AB de Villiers    4428
# G Gambhir         4223
# AM Rahane         3850
# KD Karthik        3688
# SR Watson         3614
# AT Rayudu         3326
# YK Pathan         3241
# BB McCullum       2893
# PA Patel          2874
# MK Pandey         2872
# KA Pollard        2784
# Yuvraj Singh      2765
# V Sehwag          2728
# M Vijay           2590
# SE Marsh          2489
# JH Kallis         2427
# DR Smith          2385
# Name: Total runs by each Batsman, dtype: int64

# %%
plt.figure(figsize=(12,12))
sns.barplot(top25batsmanruns,top25batsmanruns.index, palette ="hls")
plt.tight_layout()

# %% [markdown]
# ## Top Batsman = Virat Kohli

# %%
sixescountarr = []
for i in batsman :
    temp3 = deliveries.loc[(deliveries["batsman"] == i) & (deliveries["batsman_runs"]==6),:].shape[0]
    sixescountarr.append(temp3)
sixescount = pd.DataFrame({"Batsman" : batsman,"Total sixes" : sixescountarr}, columns = ["Batsman", "Total sixes"]).set_index("Batsman")
sixescount = sixescount.sort_values(by="Total sixes", ascending = False)
sixescount = sixescount["Total sixes"].nlargest(5)
sixescount
# Out:
# Batsman
# CH Gayle          327
# AB de Villiers    214
# MS Dhoni          207
# SK Raina          195
# RG Sharma         194
# Name: Total sixes, dtype: int64

# %%
plt.figure()
sns.barplot(sixescount,sixescount.index, palette ="Blues_r", orient="h")
plt.tight_layout()

# %% [markdown]
# ## Most Sixes scored by: CH GAYLE

# %%
fourscountarr = []
for i in batsman :
    temp3 = deliveries.loc[(deliveries["batsman"] == i) & (deliveries["batsman_runs"]==4),:].shape[0]
    fourscountarr.append(temp3)
fourscount = pd.DataFrame({"Batsman" : batsman,"Total fours" : fourscountarr}, columns = ["Batsman", "Total fours"]).set_index("Batsman")
fourscount = fourscount.sort_values(by="Total fours", ascending = False)
fourscount = fourscount["Total fours"].nlargest(5)
plt.figure()
splot = sns.barplot(fourscount,fourscount.index, palette ="hls", orient="h")
for p in splot.patches:
    plt.text(p.get_width(), p.get_y()+0.55*p.get_height(),'{:1.2f}'.format(p.get_width()), ha='center', va='center')
plt.tight_layout()

# %% [markdown]
# ## Most fours scored by:S Dhawan

# %%
bowlers = deliveries["bowler"].unique()
bowlers
# Out:
# array(['TS Mills', 'A Choudhary', 'YS Chahal', 'S Aravind', 'SR Watson',
#        'TM Head', 'STR Binny', 'A Nehra', 'B Kumar', 'BCJ Cutting',
#        'Rashid Khan', 'DJ Hooda', 'MC Henriques', 'Bipul Sharma',
#        'AB Dinda', 'DL Chahar', 'BA Stokes', 'Imran Tahir', 'A Zampa',
#        'R Bhatia', 'TG Southee', 'HH Pandya', 'MJ McClenaghan',
#        'JJ Bumrah', 'KH Pandya', 'KA Pollard', 'TA Boult', 'PP Chawla',
#        'SP Narine', 'CR Woakes', 'Kuldeep Yadav', 'YK Pathan', 'P Kumar',
#        'DS Kulkarni', 'MS Gony', 'S Kaushik', 'DR Smith', 'SB Jakati',
#        'Sandeep Sharma', 'MM Sharma', 'AR Patel', 'T Natarajan',
#        'MP Stoinis', 'Swapnil Singh', 'DT Christian', 'RD Chahar',
#        'Z Khan', 'CH Morris', 'PJ Cummins', 'S Nadeem', 'A Mishra',
#        'CR Brathwaite', 'B Stanlake', 'Iqbal Abdulla', 'P Negi',
#        'SK Raina', 'Tejas Baroka', 'Basil Thampi', 'SL Malinga',
#        'Harbhajan Singh', 'AS Rajpoot', 'VR Aaron', 'CJ Anderson',
# ...

# %%
eachbowlerwickets = []
for i in bowlers :    
    temp10 = deliveries.loc[(pd.isna(deliveries["player_dismissed"])==False)&(deliveries["bowler"]==i)&(deliveries["dismissal_kind"]!="run out")&(deliveries["dismissal_kind"]!="retired hurt")&(deliveries["dismissal_kind"]!="obstructing the field"),["bowler","player_dismissed"]]
    temp11 = temp10.shape[0]
    eachbowlerwickets.append(temp11)
df_eachbowlerwickets = pd.DataFrame({"Bowler" : bowlers,"Total wickets" : eachbowlerwickets}, columns = ["Bowler", "Total wickets"]).set_index("Bowler")
df_eachbowlerwickets.sort_values(by="Total wickets", ascending = False, inplace = True)
df_eachbowlerwickets
# Out:
#                  Total wickets
# Bowler
# SL Malinga                 170
# A Mishra                   156
# Harbhajan Singh            150
# PP Chawla                  149
# DJ Bravo                   147
# ...                        ...
# LRPL Taylor                  0
# RR Bose                      0
# RR Bhatkal                   0
# F du Plessis                 0
# BJ Rohrer                    0
#
# [405 rows x 1 columns]

# %%
top10bowlers = df_eachbowlerwickets["Total wickets"].nlargest(10)
plt.figure(figsize=(8,8))
splot = sns.barplot(top10bowlers,top10bowlers.index, palette ="summer", orient="h")
for p in splot.patches:
    plt.text(p.get_width(), p.get_y()+0.55*p.get_height(),'{:1.2f}'.format(p.get_width()), ha='center', va='center')
plt.tight_layout()

# %% [markdown]
# ## Top Bowler : SL Malinga

# %%
maxm = 0
match_ids = deliveries["match_id"].unique()
for i in match_ids :
    temp22 = deliveries.loc[deliveries["match_id"]==i,:].groupby(["match_id","batting_team","bowling_team","bowler"])["over"].value_counts().max()
    if temp22 > maxm :
        maxm = temp22
print(maxm)
# Out:
# 13

# %%
for i in match_ids :
    temp22 = deliveries.loc[deliveries["match_id"]==i,:].groupby(["match_id","batting_team","bowling_team","bowler"])["over"].value_counts().max()
    if temp22 == maxm :
        print(deliveries.loc[deliveries["match_id"]==i,:].groupby(["match_id","batting_team","bowling_team","bowler"])["over"].value_counts().nlargest(1))
# Out:
# match_id  batting_team                 bowling_team         bowler    over
# 388       Royal Challengers Bangalore  Sunrisers Hyderabad  DW Steyn  1       13
# Name: over, dtype: int64
# match_id  batting_team     bowling_team      bowler     over
# 536       Kings XI Punjab  Rajasthan Royals  CH Morris  1       13
# Name: over, dtype: int64

# %%
mostbowlsfacedarr = []
for i in batsman :
    mostbowlsfacedarr.append(deliveries.loc[(deliveries["batsman"]==i)&(deliveries["wide_runs"]==0),:].shape[0])
df_mostbowlsfaced = pd.DataFrame({"batsman" : batsman,"Totals balls faced" : mostbowlsfacedarr}, columns = ["batsman", "Totals balls faced"]).set_index("batsman")
df_mostbowlsfaced.sort_values(by="Totals balls faced", ascending = False, inplace = True)
df_mostbowlsfaced
# Out:
#                 Totals balls faced
# batsman
# V Kohli                       4114
# SK Raina                      3917
# RG Sharma                     3744
# S Dhawan                      3671
# G Gambhir                     3404
# ...                            ...
# C Nanda                          1
# S Lamichhane                     1
# U Kaul                           1
# YA Abdulla                       1
# V Pratap Singh                   1
#
# [516 rows x 1 columns]

# %%
top10mostbowlsfaced = df_mostbowlsfaced["Totals balls faced"].nlargest(10)
top10mostbowlsfaced
# Out:
# batsman
# V Kohli       4114
# SK Raina      3917
# RG Sharma     3744
# S Dhawan      3671
# G Gambhir     3404
# RV Uthappa    3384
# DA Warner     3306
# MS Dhoni      3215
# AM Rahane     3136
# CH Gayle      2981
# Name: Totals balls faced, dtype: int64

# %%
plt.figure(figsize=(8,8))
splot = sns.barplot(top10mostbowlsfaced,top10mostbowlsfaced.index, palette ="autumn", orient="h")
for p in splot.patches:
    plt.text(p.get_width(), p.get_y()+0.55*p.get_height(),'{:1.2f}'.format(p.get_width()), ha='center', va='center')
plt.tight_layout()

# %%
deliveries["bowler"].value_counts()
# Out:
# Harbhajan Singh    3451
# A Mishra           3172
# PP Chawla          3157
# R Ashwin           3016
# SL Malinga         2974
#                    ...
# RA Tripathi           6
# C Ganapathy           6
# SPD Smith             2
# SN Khan               2
# AC Gilchrist          1
# Name: bowler, Length: 405, dtype: int64

# %%
strikerateeachbatsman = []
for pos,name in enumerate(batsman) :
    strikerateeachbatsman.append(100*(totalrunseachbatsmanarr[pos]/mostbowlsfacedarr[pos]))
pd.Series(strikerateeachbatsman, index = batsman)
# Out:
# DA Warner       143.405929
# S Dhawan        126.178153
# MC Henriques    128.174603
# Yuvraj Singh    130.301602
# DJ Hooda        129.539952
#                    ...
# A Turner         40.000000
# H Brar          183.333333
# S Rutherford    151.851852
# P Raj             0.000000
# S Singh         100.000000
# Length: 516, dtype: float64

# %%
pd.Series(strikerateeachbatsman, index = batsman).nlargest(10)
# Out:
# S Sharma         266.666667
# B Stanlake       250.000000
# Umar Gul         205.263158
# RS Sodhi         200.000000
# AD Russell       191.644562
# H Brar           183.333333
# K Gowtham        178.313253
# LJ Wright        176.666667
# Shahid Afridi    176.086957
# SP Narine        175.327511
# dtype: float64

# %%
matches["player_of_match"].value_counts()
# Out:
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
#                   ..
# K Paul             1
# TA Boult           1
# KV Sharma          1
# SA Yadav           1
# AD Mascarenhas     1
# Name: player_of_match, Length: 226, dtype: int64

# %% [markdown]
# # Result:
# ## 1.The most successful teams:
# ### -Mumbai Indians
# ### -XI Punjab
# ### -Royal Challengers Bangalore
# ### -Kolkata Knight Riders
# ### -Chennai Super Kings
#
# ## 2.Suggest teams or players a company should endorse for its products.
# ## 3.You can choose any of the tool of your choice
